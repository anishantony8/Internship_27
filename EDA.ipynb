# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel (r'C:\Users\anish\customer_retention_dataset.xlsx', sheet_name='codedsheet')
df.head(10)
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
# 5                      1                    3
# 6                      0                    4
# 7                      0                    4
# 8                      1                    1
# 9                      1                    3
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# 5                                 Noida
# 6                                 Delhi
# 7                                 Delhi
# 8                                 Solan
# 9                                 Delhi
#
# ...

# %%
df1 = pd.read_excel (r'C:\Users\anish\customer_retention_dataset.xlsx', sheet_name='datasheet')
df1.head(10)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
# 5                Female         31-40 years
# 6                  Male         41-50 yaers
# 7                  Male         41-50 yaers
# 8                Female  Less than 20 years
# 9                Female         31-40 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# 5                                 Noida
# 6                                 Delhi
# 7                                 Delhi
# 8                                 Solan
# 9                                 Delhi
#
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?',
#        '10 What is the operating system (OS) of your device?            ',
#        '11 What browser do you run on your device to access the website?                                                  ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?',
#        '13 After first visit, how do you reach the online retail store?',
#        '14 How much time do you explore the e- retail store before making a purchase decision?',
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                              --------------  -----
#  0   1Gender of respondent                                                                                               269 non-null    int64
#  1   2 How old are you?                                                                                                  269 non-null    int64
#  2   3 Which city do you shop online from?                                                                               269 non-null    object
#  3   4 What is the Pin Code of where you shop online from?                                                               269 non-null    int64
# ...

# %%
df.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#null values
[i for i in df.columns if df[i].isnull().sum()>0]
# Out:
# []

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='2 How old are you? ', y='3 Which city do you shop online from?', data=df)

# %%
sns.catplot(x='2 How old are you? ', y='3 Which city do you shop online from?', data=df)

# %%
sns.factorplot(x='2 How old are you? ',y='3 Which city do you shop online from?', hue='1Gender of respondent',data=df,kind ='bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.countplot(x='2 How old are you? ', data = df1,hue='1Gender of respondent')
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %%
sns.factorplot(x='5 Since How Long You are Shopping Online ?',y='3 Which city do you shop online from?', hue='1Gender of respondent',data=df,kind ='bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.countplot(x='5 Since How Long You are Shopping Online ?', data = df1)
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
df['4 What is the Pin Code of where you shop online from?'].unique()
# Out:
# array([110009, 110030, 201308, 132001, 530068, 110011, 110018, 173229,
#        110039, 244001, 122018, 201310, 560037, 203207, 250001, 201005,
#        110044, 201306, 560010, 201305, 110042, 132036, 560018, 110008,
#        560002, 201303, 201312, 203202, 560001, 201304, 560003, 110014,
#        560013, 173212, 122009, 201009, 201008, 201001, 203001],
#       dtype=int64)

# %%
sns.catplot(x='4 What is the Pin Code of where you shop online from?', hue='1Gender of respondent',data=df1, kind="count",height=25, aspect=.9)

# %%
sns.catplot(x='4 What is the Pin Code of where you shop online from?', hue='6 How many times you have made an online purchase in the past 1 year?',data=df1, kind="count",height=35, aspect=.9)

# %%
sns.factorplot(x='6 How many times you have made an online purchase in the past 1 year?',y='3 Which city do you shop online from?', hue='1Gender of respondent',data=df,kind ='bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='7 How do you access the internet while shopping on-line?',y='3 Which city do you shop online from?',data=df,kind ='bar',hue='1Gender of respondent')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.countplot(x='7 How do you access the internet while shopping on-line?',data=df1,hue='1Gender of respondent')
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
sns.factorplot(x='8 Which device do you use to access the online shopping?',y='3 Which city do you shop online from?',data=df,kind ='bar',hue='1Gender of respondent')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.countplot(x='8 Which device do you use to access the online shopping?',data=df1,hue='1Gender of respondent')
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
sns.factorplot(x='9 What is the screen size of your mobile device?',y='3 Which city do you shop online from?',data=df,kind ='bar',hue='1Gender of respondent')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.countplot(x='9 What is the screen size of your mobile device?',data=df,hue='2 How old are you? ')
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?', ylabel='count'>

# %%
os = ['Window/windows Mobile','Android','IOS/Mac']
os_type=df1['10 What is the operating system (OS) of your device?            '].value_counts().values
plt.pie(os_type,labels=os,autopct='%1.2f%%')

# %%
browser = ['Google chrome','Safari','Mozilla Firefox','Opera']
browser_type=df['11 What browser do you run on your device to access the website?                                                  '].value_counts().values
plt.pie(browser_type,labels=browser,autopct='%1.2f%%')

# %%
sns.countplot(x='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?',data=df1)
# Out:
# <AxesSubplot:xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?', ylabel='count'>

# %%
sns.countplot(x='17 Why did you abandon the “Bag”, “Shopping Cart”?', data=df1)
# Out:
# <AxesSubplot:xlabel='17 Why did you abandon the “Bag”, “Shopping Cart”?', ylabel='count'>

# %%
sns.countplot(x='18 The content on the website must be easy to read and understand', data=df1)
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %%
sns.countplot(x='19 Information on similar product to the one highlighted  is important for product comparison', data=df1)
# Out:
# <AxesSubplot:xlabel='19 Information on similar product to the one highlighted  is important for product comparison', ylabel='count'>

# %%
sns.countplot(x='20 Complete information on listed seller and product being offered is important for purchase decision.', data=df1)
# Out:
# <AxesSubplot:xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %%
sns.countplot(x='21 All relevant information on listed products must be stated clearly', data=df1)
# Out:
# <AxesSubplot:xlabel='21 All relevant information on listed products must be stated clearly', ylabel='count'>

# %%
sns.countplot(x='22 Ease of navigation in website', data=df1)
# Out:
# <AxesSubplot:xlabel='22 Ease of navigation in website', ylabel='count'>

# %%
sns.countplot(x='23 Loading and processing speed', data=df1)
# Out:
# <AxesSubplot:xlabel='23 Loading and processing speed', ylabel='count'>

# %%
sns.countplot(x='24 User friendly Interface of the website', data=df1)
# Out:
# <AxesSubplot:xlabel='24 User friendly Interface of the website', ylabel='count'>

# %%
sns.countplot(x='25 Convenient Payment methods', data=df1)
# Out:
# <AxesSubplot:xlabel='25 Convenient Payment methods', ylabel='count'>

# %%
sns.countplot(x='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', data=df1)
# Out:
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %%
sns.countplot(x='27 Empathy (readiness to assist with queries) towards the customers', data=df1)
# Out:
# <AxesSubplot:xlabel='27 Empathy (readiness to assist with queries) towards the customers', ylabel='count'>

# %%
sns.countplot(x='28 Being able to guarantee the privacy of the customer', data=df1)
# Out:
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %%
sns.countplot(x='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', data=df1)
# Out:
# <AxesSubplot:xlabel='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', ylabel='count'>

# %%
sns.countplot(x='30 Online shopping gives monetary benefit and discounts', data=df1)
# Out:
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %%
sns.countplot(x='31 Enjoyment is derived from shopping online', data=df1)
# Out:
# <AxesSubplot:xlabel='31 Enjoyment is derived from shopping online', ylabel='count'>

# %%
sns.countplot(x='32 Shopping online is convenient and flexible', data=df1)
# Out:
# <AxesSubplot:xlabel='32 Shopping online is convenient and flexible', ylabel='count'>

# %%
sns.countplot(x='33 Return and replacement policy of the e-tailer is important for purchase decision', data=df1)
# Out:
# <AxesSubplot:xlabel='33 Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %%
sns.countplot(x='34 Gaining access to loyalty programs is a benefit of shopping online', data=df1)
# Out:
# <AxesSubplot:xlabel='34 Gaining access to loyalty programs is a benefit of shopping online', ylabel='count'>

# %%
sns.countplot(x='35 Displaying quality Information on the website improves satisfaction of customers', data=df1)
# Out:
# <AxesSubplot:xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %%
sns.countplot(x='36 User derive satisfaction while shopping on a good quality website or application', data=df1)
# Out:
# <AxesSubplot:xlabel='36 User derive satisfaction while shopping on a good quality website or application', ylabel='count'>

# %%
sns.countplot(x='37 Net Benefit derived from shopping online can lead to users satisfaction', data=df1)
# Out:
# <AxesSubplot:xlabel='37 Net Benefit derived from shopping online can lead to users satisfaction', ylabel='count'>

# %%
sns.countplot(x='38 User satisfaction cannot exist without trust', data=df1)
# Out:
# <AxesSubplot:xlabel='38 User satisfaction cannot exist without trust', ylabel='count'>

# %%
sns.countplot(x='39 Offering a wide variety of listed product in several category', data=df1)
# Out:
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='count'>

# %%
sns.countplot(x='40 Provision of complete and relevant product information', data=df1)
# Out:
# <AxesSubplot:xlabel='40 Provision of complete and relevant product information', ylabel='count'>

# %%
sns.countplot(x='41 Monetary savings', data=df1)
# Out:
# <AxesSubplot:xlabel='41 Monetary savings', ylabel='count'>

# %%
sns.countplot(x='42 The Convenience of patronizing the online retailer', data=df1)
# Out:
# <AxesSubplot:xlabel='42 The Convenience of patronizing the online retailer', ylabel='count'>

# %%
sns.countplot(x='43 Shopping on the website gives you the sense of adventure', data=df1)
# Out:
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='count'>

# %%
sns.countplot(x='44 Shopping on your preferred e-tailer enhances your social status', data=df1)
# Out:
# <AxesSubplot:xlabel='44 Shopping on your preferred e-tailer enhances your social status', ylabel='count'>

# %%
sns.countplot(x='45 You feel gratification shopping on your favorite e-tailer', data=df1)
# Out:
# <AxesSubplot:xlabel='45 You feel gratification shopping on your favorite e-tailer', ylabel='count'>

# %%
sns.countplot(x='46 Shopping on the website helps you fulfill certain roles', data=df1)
# Out:
# <AxesSubplot:xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='count'>

# %%
sns.countplot(x='47 Getting value for money spent', data=df1)
# Out:
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %%
chart = sns.countplot(x='From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in, Paytm.com'),
#  Text(1, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com'),
#  Text(6, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(7, 0, 'Amazon.in'),
#  Text(8, 0, 'Amazon.in, Flipkart.com, Paytm.com')]

# %%
chart = sns.countplot(x='Easy to use website or application', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Paytm.com'),
#  Text(1, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com'),
#  Text(6, 0, 'Amazon.in, Flipkart.com, Myntra.com'),
#  Text(7, 0, 'Amazon.in'),
#  Text(8, 0, 'Amazon.in, Paytm.com'),
#  Text(9, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Easy to use website or application', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Paytm.com'),
#  Text(1, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com'),
#  Text(6, 0, 'Amazon.in, Flipkart.com, Myntra.com'),
#  Text(7, 0, 'Amazon.in'),
#  Text(8, 0, 'Amazon.in, Paytm.com'),
#  Text(9, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Visual appealing web-page layout', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Flipkart.com'),
#  Text(1, 0, 'Amazon.in, Myntra.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(4, 0, 'Myntra.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com'),
#  Text(6, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(7, 0, 'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com'),
#  Text(8, 0, 'Flipkart.com, Myntra.com'),
#  Text(9, 0, 'Amazon.in')]

# %%
chart = sns.countplot(x='Wild variety of product on offer', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Flipkart.com'),
#  Text(1, 0, 'Flipkart.com, Myntra.com'),
#  Text(2, 0, 'Amazon.in, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com'),
#  Text(4, 0, 'Myntra.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com, Paytm.com'),
#  Text(6, 0, 'Amazon.in'),
#  Text(7, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(8, 0, 'Paytm.com')]

# %%
chart = sns.countplot(x='Complete, relevant description information of products', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Snapdeal.com'),
#  Text(1, 0, 'Amazon.in, Flipkart.com, Myntra.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com, Paytm.com'),
#  Text(6, 0, 'Flipkart.com, Snapdeal.com'),
#  Text(7, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(8, 0, 'Amazon.in'),
#  Text(9, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(10, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Fast loading website speed of website and application', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Snapdeal.com'),
#  Text(1, 0, 'Amazon.in, Flipkart.com, Myntra.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(4, 0, 'Amazon.in'),
#  Text(5, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(6, 0, 'Amazon.in, Flipkart.com, Paytm.com'),
#  Text(7, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(8, 0, 'Amazon.in, Flipkart.com'),
#  Text(9, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Reliability of the website or application', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Paytm.com'),
#  Text(1, 0, 'Myntra.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Paytm.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(6, 0, 'Amazon.in'),
#  Text(7, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(8, 0, 'Amazon.in, Flipkart.com'),
#  Text(9, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Quickness to complete purchase', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Paytm.com'),
#  Text(1, 0, 'Amazon.com, Flipkart.com, Myntra.com'),
#  Text(2, 0, 'Amazon.com, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.com, Flipkart.com, Paytm.com'),
#  Text(4, 0, 'Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal'),
#  Text(5, 0, 'Amazon.com'),
#  Text(6, 0, 'Flipkart.com, Myntra.com, Snapdeal'),
#  Text(7, 0, 'Amazon.com, Flipkart.com'),
#  Text(8, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Availability of several payment options', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Patym.com'),
#  Text(1, 0, 'Amazon.in, Flipkart.com, Myntra.com'),
#  Text(2, 0, 'Patym.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com'),
#  Text(6, 0, 'Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(7, 0, 'Amazon.in, Patym.com'),
#  Text(8, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(9, 0, 'Amazon.in'),
#  Text(10, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Speedy order delivery ', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in'),
#  Text(1, 0, 'Amazon.in, Flipkart.com'),
#  Text(2, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(3, 0, 'Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Myntra.com'),
#  Text(5, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Privacy of customers’ information', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in'),
#  Text(1, 0, 'Myntra.com'),
#  Text(2, 0, 'Amazon.in, Flipkart.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Paytm.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(5, 0, 'Paytm.com'),
#  Text(6, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(7, 0, 'Amazon.in, Flipkart.com'),
#  Text(8, 0, 'Amazon.in, Flipkart.com, Paytm.com'),
#  Text(9, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(10, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Security of customer financial information', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in'),
#  Text(1, 0, 'Myntra.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(4, 0, 'Paytm.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(6, 0, 'Flipkart.com'),
#  Text(7, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(8, 0, 'Amazon.in, Flipkart.com'),
#  Text(9, 0, 'Amazon.in, Flipkart.com, Paytm.com'),
#  Text(10, 0, 'Amazon.in, Snapdeal.com')]

# %%
chart = sns.countplot(x='Perceived Trustworthiness', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Flipkart.com'),
#  Text(1, 0, 'Myntra.com'),
#  Text(2, 0, 'Amazon.in, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(4, 0, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#  Text(5, 0, 'Amazon.in'),
#  Text(6, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com'),
#  Text(7, 0, 'Amazon.in, Flipkart.com'),
#  Text(8, 0, 'Amazon.in, Flipkart.com, Paytm.com')]

# %%
chart = sns.countplot(x='Presence of online assistance through multi-channel', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Paytm.com'),
#  Text(1, 0, 'Amazon.in, Flipkart.com, Myntra.com'),
#  Text(2, 0, 'Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal'),
#  Text(4, 0, 'Amazon.in, Myntra.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com, Paytm.com'),
#  Text(6, 0, 'Amazon.in'),
#  Text(7, 0, 'Amazon.in, Flipkart.com'),
#  Text(8, 0, 'Amazon.in, Snapdeal'),
#  Text(9, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Longer time to get logged in (promotion, sales period)', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in'),
#  Text(1, 0, 'Amazon.in, Flipkart.com'),
#  Text(2, 0, 'Myntra.com'),
#  Text(3, 0, 'Snapdeal.com'),
#  Text(4, 0, 'Flipkart.com, Paytm.com'),
#  Text(5, 0, 'Flipkart.com, Paytm.com, Snapdeal.com'),
#  Text(6, 0, 'Amazon.in, Flipkart.com, Snapdeal.com'),
#  Text(7, 0, 'Paytm.com'),
#  Text(8, 0, 'Amazon.in, Paytm.com'),
#  Text(9, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Longer time in displaying graphics and photos (promotion, sales period)', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in'),
#  Text(1, 0, 'Myntra.com'),
#  Text(2, 0, 'Myntra.com, Snapdeal.com'),
#  Text(3, 0, 'Paytm.com'),
#  Text(4, 0, 'Amazon.in, Paytm.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com'),
#  Text(6, 0, 'Amazon.in, Myntra.com, Snapdeal.com'),
#  Text(7, 0, 'Flipkart.com, Snapdeal.com'),
#  Text(8, 0, 'Snapdeal.com'),
#  Text(9, 0, 'Flipkart.com')]

# %%
chart = sns.countplot(x='Late declaration of price (promotion, sales period)', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Flipkart.com'),
#  Text(1, 0, 'snapdeal.com'),
#  Text(2, 0, 'Myntra.com'),
#  Text(3, 0, 'Paytm.com'),
#  Text(4, 0, 'Amazon.in, Paytm.com'),
#  Text(5, 0, 'Amazon.in'),
#  Text(6, 0, 'Paytm.com, snapdeal.com'),
#  Text(7, 0, 'Amazon.in, Flipkart.com')]

# %%
chart = sns.countplot(x='Longer page loading time (promotion, sales period)', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Flipkart.com'),
#  Text(1, 0, 'Snapdeal.com'),
#  Text(2, 0, 'Myntra.com'),
#  Text(3, 0, 'Paytm.com'),
#  Text(4, 0, 'Amazon.in, Paytm.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com'),
#  Text(6, 0, 'Amazon.in, Snapdeal.com'),
#  Text(7, 0, 'Flipkart.com, Snapdeal.com'),
#  Text(8, 0, 'Paytm.com, Snapdeal.com'),
#  Text(9, 0, 'Amazon.in'),
#  Text(10, 0, 'Amazon.in, Paytm.com, Myntra.com')]

# %%
chart = sns.countplot(x='Limited mode of payment on most products (promotion, sales period)', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in'),
#  Text(1, 0, 'Snapdeal.com'),
#  Text(2, 0, 'Paytm.com'),
#  Text(3, 0, 'Amazon.in, Paytm.com'),
#  Text(4, 0, 'Flipkart.com'),
#  Text(5, 0, 'Amazon.in, Flipkart.com'),
#  Text(6, 0, 'Paytm.com, Snapdeal.com'),
#  Text(7, 0, 'Myntra.com, Snapdeal.com')]

# %%
chart = sns.countplot(x='Longer delivery period', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Paytm.com'),
#  Text(1, 0, 'Snapdeal.com'),
#  Text(2, 0, 'Flipkart.com'),
#  Text(3, 0, 'Amazon.in'),
#  Text(4, 0, 'Paytm.com, Snapdeal.com'),
#  Text(5, 0, 'Myntra.com')]

# %%
chart = sns.countplot(x='Change in website/Application design', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Flipkart.com'),
#  Text(1, 0, 'Amazon.in'),
#  Text(2, 0, 'Paytm.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com'),
#  Text(4, 0, 'Myntra.com'),
#  Text(5, 0, 'Snapdeal.com'),
#  Text(6, 0, 'Flipkart.com, Myntra.com')]

# %%
chart = sns.countplot(x='Frequent disruption when moving from one page to another', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in'),
#  Text(1, 0, 'Myntra.com'),
#  Text(2, 0, 'Paytm.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com'),
#  Text(4, 0, 'Snapdeal.com'),
#  Text(5, 0, 'Flipkart.com'),
#  Text(6, 0, 'Myntra.com, Snapdeal.com'),
#  Text(7, 0, 'Flipkart.com, Snapdeal.com')]

# %%
chart = sns.countplot(x='Website is as efficient as before', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Amazon.in'),
#  Text(1, 0, 'Amazon.in, Flipkart.com'),
#  Text(2, 0, 'Amazon.in, Flipkart.com, Paytm.com'),
#  Text(3, 0, 'Paytm.com'),
#  Text(4, 0, 'Snapdeal.com'),
#  Text(5, 0, 'Myntra.com, Snapdeal.com'),
#  Text(6, 0, 'Flipkart.com'),
#  Text(7, 0, 'Amazon.in, Paytm.com')]

# %%
chart = sns.countplot(x='Which of the Indian online retailer would you recommend to a friend?', data=df1)
chart.set_xticklabels(chart.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Flipkart.com'),
#  Text(1, 0, 'Amazon.in, Myntra.com'),
#  Text(2, 0, 'Amazon.in, Paytm.com, Myntra.com'),
#  Text(3, 0, 'Amazon.in, Flipkart.com'),
#  Text(4, 0, 'Amazon.in, Paytm.com'),
#  Text(5, 0, 'Flipkart.com, Paytm.com, Myntra.com, snapdeal.com'),
#  Text(6, 0, 'Amazon.in'),
#  Text(7, 0, 'Amazon.in, Flipkart.com, Myntra.com')]

# %%
pd.crosstab(index=df1['3 Which city do you shop online from?'], 
                             columns=[df1['1Gender of respondent'],
                                      df1['2 How old are you? ']],
                             margins=True)
# Out:
# 1Gender of respondent                      Female                          \
# 2 How old are you?                    21-30 years 31-40 years 41-50 yaers
# 3 Which city do you shop online from?
# Bangalore                                      18           0          12
# Bulandshahr                                     0           0           0
# Delhi                                           7          10           1
# Ghaziabad                                       0           8           5
# Greater Noida                                  14          17          11
# Gurgaon                                         0           0           0
# Karnal                                          8           7           4
# Merrut                                          5           1           3
# Moradabad                                       0           0           0
# Noida                                           1           4           7
# ...

# %%
pd.crosstab(index=df1['4 What is the Pin Code of where you shop online from?'], 
                             columns=[df1['3 Which city do you shop online from?'],
                                      ],
                             margins=True)
# Out:
# 3 Which city do you shop online from?               Bangalore   Bulandshahr  \
# 4 What is the Pin Code of where you shop online...
# 110008                                                       0            0
# 110009                                                       0            0
# 110011                                                       0            0
# 110014                                                       0            0
# 110018                                                       0            0
# 110030                                                       0            0
# 110039                                                       0            0
# 110042                                                       0            0
# 110044                                                       0            0
# 122009                                                       0            0
# 122018                                                       0            0
# ...

# %%
pd.crosstab(index=df1['5 Since How Long You are Shopping Online ?'], 
                             columns=[df1['3 Which city do you shop online from?']
                                      ],
                             margins=True)
# Out:
# 3 Which city do you shop online from?       Bangalore   Bulandshahr  Delhi  \
# 5 Since How Long You are Shopping Online ?
# 1-2 years                                            0            2      1
# 2-3 years                                           14            0     13
# 3-4 years                                            8            0      8
# Above 4 years                                       12            0     20
# Less than 1 year                                     3            0     16
# All                                                 37            2     58
#
# 3 Which city do you shop online from?       Ghaziabad  Greater Noida  \
# 5 Since How Long You are Shopping Online ?
# 1-2 years                                           5              0
# 2-3 years                                           5              4
# 3-4 years                                           0              7
# Above 4 years                                       3             22
# ...

# %%
pd.crosstab(index=df1['5 Since How Long You are Shopping Online ?'], 
                             columns=[df1['6 How many times you have made an online purchase in the past 1 year?']
                              ],
                             margins=True)
# Out:
# 6 How many times you have made an online purchase in the past 1 year?  11-20 times  \
# 5 Since How Long You are Shopping Online ?
# 1-2 years                                                                        1
# 2-3 years                                                                        8
# 3-4 years                                                                        4
# Above 4 years                                                                   15
# Less than 1 year                                                                 1
# All                                                                             29
#
# 6 How many times you have made an online purchase in the past 1 year?  21-30 times  \
# 5 Since How Long You are Shopping Online ?
# 1-2 years                                                                        1
# 2-3 years                                                                        0
# ...

# %%
pd.crosstab(index=df1['7 How do you access the internet while shopping on-line?'], 
                             columns=[df1['8 Which device do you use to access the online shopping?']
                              ],
                             margins=True)
# Out:
# 8 Which device do you use to access the online shopping?  Desktop  Laptop  \
# 7 How do you access the internet while shopping...
# Dial-up                                                         4       0
# Mobile Internet                                                26      53
# Wi-Fi                                                           0      33
# All                                                            30      86
#
# 8 Which device do you use to access the online shopping?  Smartphone  Tablet  \
# 7 How do you access the internet while shopping...
# Dial-up                                                            0       0
# Mobile Internet                                                  104       6
# Wi-Fi                                                             37       6
# All                                                              141      12
#
# 8 Which device do you use to access the online shopping?  All
# ...

# %%
pd.crosstab(index=df1['9 What is the screen size of your mobile device?\t\t\t\t                                        '], 
                             columns=[
                              df1['10 What is the operating system (OS) of your device?\t\t\t\t                                          ']],
                             margins=True)
# Out:
# 10 What is the operating system (OS) of your device?				                                            Android  \
# 9 What is the screen size of your mobile device...
# 4.7 inches                                                                                                0
# 5 inches                                                                                                  6
# 5.5 inches                                                                                               61
# Others                                                                                                   18
# All                                                                                                      85
#
# 10 What is the operating system (OS) of your device?				                                            IOS/Mac  \
# 9 What is the screen size of your mobile device...
# 4.7 inches                                                                                               29
# ...

# %%
pd.crosstab(index=df1['10 What is the operating system (OS) of your device?\t\t\t\t                                          '], 
                             columns=[df1['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '],
                              df1['11 What browser do you run on your device to access the website?\t\t\t                                                          ']],
                             margins=True)
# Out:
# 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                    Content Marketing  \
# 11 What browser do you run on your device to access the website?			                                                                                              Mozilla Firefox
# 10 What is the operating system (OS) of your de...
# Android                                                                                                                                                                        5
# IOS/Mac                                                                                                                                                                        0
# Window/windows Mobile                                                                                                                                                          0
# ...

# %%
pd.crosstab(index=df1['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '], 
                             columns=[df1['15 What is your preferred payment Option?                                                                 '],
                              df1['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?']],
                             margins=True)
# Out:
# 15 What is your preferred payment Option?                                                                    Cash on delivery (CoD)  \
# 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?             Frequently
# 14 How much time do you explore the e- retail s...
# 1-5 mins                                                                                                                          0
# 11-15 mins                                                                                                                        7
# 6-10 mins                                                                                                                         0
# Less than 1 min                                                                                                                   0
# more than 15 mins                                                                                                                 0
# ...

# %%
pd.crosstab(index= df1['17 Why did you abandon the “Bag”, “Shopping Cart”?'],columns=[df1['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '], 
                             df1['15 What is your preferred payment Option?                                                                 ']
                             ],
                             margins=True)
# Out:
# 14 How much time do you explore the e- retail store before making a purchase decision?                                                                                  1-5 mins  \
# 15 What is your preferred payment Option?                                                                                                                 Cash on delivery (CoD)
# 17 Why did you abandon the “Bag”, “Shopping Cart”?
# Better alternative offer                                                                                                                                                       0
# Change in price                                                                                                                                                                0
# Lack of trust                                                                                                                                                                  0
# ...

# %%
pd.crosstab(index=df1['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '], 
                             columns=[df1['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?']],
                             margins=True)
# Out:
# 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?  Frequently  \
# 14 How much time do you explore the e- retail s...
# 1-5 mins                                                                                                               0
# 11-15 mins                                                                                                             7
# 6-10 mins                                                                                                              0
# Less than 1 min                                                                                                        0
# more than 15 mins                                                                                                     28
# All                                                                                                                   35
#
# ...

# %%
pd.crosstab(index=df1['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '], 
                             columns=[df1['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'],df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?               Frequently  \
# 17 Why did you abandon the “Bag”, “Shopping Cart”?                                                           Better alternative offer
# 14 How much time do you explore the e- retail s...
# 1-5 mins                                                                                                                            0
# 11-15 mins                                                                                                                          7
# 6-10 mins                                                                                                                           0
# Less than 1 min                                                                                                                     0
# ...

# %%
pd.crosstab(index=df1['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '], 
                             columns=[df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Better alternative offer  \
# 14 How much time do you explore the e- retail s...
# 1-5 mins                                                                   0
# 11-15 mins                                                                18
# 6-10 mins                                                                 30
# Less than 1 min                                                            7
# more than 15 mins                                                         78
# All                                                                      133
#
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Change in price  \
# 14 How much time do you explore the e- retail s...
# 1-5 mins                                                          0
# 11-15 mins                                                        0
# 6-10 mins                                                        29
# ...

# %%
df.skew()
# Out:
# C:\Users\anish\AppData\Local\Temp/ipykernel_10020/1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# 1Gender of respondent                                                                                                -0.723007
# 2 How old are you?                                                                                                    0.063243
# 4 What is the Pin Code of where you shop online from?                                                                 1.748322
# 5 Since How Long You are Shopping Online ?                                                                           -0.554705
# 6 How many times you have made an online purchase in the past 1 year?                                                 0.227755
# ...

# %%
df.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 4 What is the Pin Code of where you shop online...               0.260696
# 5 Since How Long You are Shopping Online ?                      -0.046005
# 6 How many times you have made an online purcha...               0.076121
# 7 How do you access the internet while shopping...               0.329599
# 8 Which device do you use to access the online ...              -0.241847
# 9 What is the screen size of your mobile device?                -0.058760
# 10 What is the operating system (OS) of your de...              -0.038207
# 11 What browser do you run on your device to ac...              -0.116712
# 12 Which channel did you follow to arrive at yo...              -0.166694
# 13 After first visit, how do you reach the onli...               0.179558
# ...

# %%
pd.crosstab(index = df1['3 Which city do you shop online from?'],columns=[df1['4 What is the Pin Code of where you shop online from?']],
                             margins=True)
# Out:
# 4 What is the Pin Code of where you shop online from?  110008  110009  110011  \
# 3 Which city do you shop online from?
# Bangalore                                                   0       0       0
# Bulandshahr                                                 0       0       0
# Delhi                                                       7       4       7
# Ghaziabad                                                   0       0       0
# Greater Noida                                               0       0       0
# Gurgaon                                                     0       0       0
# Karnal                                                      0       0       0
# Merrut                                                      0       0       0
# Moradabad                                                   0       0       0
# Noida                                                       0       0       0
# ...

# %%
table = pd.pivot_table(df1, index =['3 Which city do you shop online from?', '4 What is the Pin Code of where you shop online from?'])
  
table
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:507: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
# Empty DataFrame
# Columns: []
# ...

# %%
df1.groupby('7 How do you access the internet while shopping on-line?').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('8 Which device do you use to access the online shopping?').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('9 What is the screen size of your mobile device?\t\t\t\t                                        ').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('10 What is the operating system (OS) of your device?\t\t\t\t                                          ').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('11 What browser do you run on your device to access the website?\t\t\t                                                          ').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('15 What is your preferred payment Option?                                                                 ').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df1.groupby('17 Why did you abandon the “Bag”, “Shopping Cart”?').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
pd.crosstab(index=df1['18 The content on the website must be easy to read and understand'], 
                             columns=[df1['19 Information on similar product to the one highlighted  is important for product comparison'],df1['20 Complete information on listed seller and product being offered is important for purchase decision.']],
                             margins=True)
# Out:
# 19 Information on similar product to the one highlighted  is important for product comparison          Agree (4)  \
# 20 Complete information on listed seller and product being offered is important for purchase decision. Agree (4)
# 18 The content on the website must be easy to r...
# Agree (4)                                                                                                     19
# Indifferent (3)                                                                                                0
# Strongly agree (5)                                                                                            20
# Strongly disagree (1)                                                                                          0
# All                                                                                                           39
#
# 19 Information on similar product to the one highlighted  is important for product comparison                           \
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?',
#        '10 What is the operating system (OS) of your device?            ',
#        '11 What browser do you run on your device to access the website?                                                  ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?',
#        '13 After first visit, how do you reach the online retail store?',
#        '14 How much time do you explore the e- retail store before making a purchase decision?',
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
pd.crosstab(index=df1['2 How old are you? '], 
                             columns=[df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Better alternative offer  \
# 2 How old are you?
# 21-30 years                                                               46
# 31-40 years                                                               43
# 41-50 yaers                                                               26
# 51 years and above                                                        12
# Less than 20 years                                                         6
# All                                                                      133
#
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Change in price  \
# 2 How old are you?
# 21-30 years                                                       8
# 31-40 years                                                      12
# 41-50 yaers                                                      14
# 51 years and above                                                3
# ...

# %%
pd.crosstab(index=df1['3 Which city do you shop online from?'], 
                             columns=[df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Better alternative offer  \
# 3 Which city do you shop online from?
# Bangalore                                                                 22
# Bulandshahr                                                                2
# Delhi                                                                     20
# Ghaziabad                                                                  8
# Greater Noida                                                             24
# Gurgaon                                                                   11
# Karnal                                                                    16
# Merrut                                                                     3
# Moradabad                                                                  0
# Noida                                                                     17
# Solan                                                                     10
# ...

# %%
pd.crosstab(index=df1['4 What is the Pin Code of where you shop online from?'], 
                             columns=[df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Better alternative offer  \
# 4 What is the Pin Code of where you shop online...
# 110008                                                                     6
# 110009                                                                     0
# 110011                                                                     2
# 110014                                                                     3
# 110018                                                                     0
# 110030                                                                     0
# 110039                                                                     0
# 110042                                                                     0
# 110044                                                                     9
# 122009                                                                     4
# ...

# %%
pd.crosstab(index=df1['5 Since How Long You are Shopping Online ?'], 
                             columns=[df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Better alternative offer  \
# 5 Since How Long You are Shopping Online ?
# 1-2 years                                                                 10
# 2-3 years                                                                 33
# 3-4 years                                                                 19
# Above 4 years                                                             43
# Less than 1 year                                                          28
# All                                                                      133
#
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Change in price  \
# 5 Since How Long You are Shopping Online ?
# 1-2 years                                                         5
# 2-3 years                                                         4
# 3-4 years                                                         8
# ...

# %%
pd.crosstab(index=df1['6 How many times you have made an online purchase in the past 1 year?'], 
                             columns=[df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Better alternative offer  \
# 6 How many times you have made an online purcha...
# 11-20 times                                                               23
# 21-30 times                                                                4
# 31-40 times                                                               19
# 41 times and above                                                        21
# 42 times and above                                                         0
# Less than 10 times                                                        66
# All                                                                      133
#
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Change in price  \
# 6 How many times you have made an online purcha...
# 11-20 times                                                       0
# 21-30 times                                                       5
# ...

# %%
pd.crosstab(index=df1['7 How do you access the internet while shopping on-line?'], 
                             columns=[df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Better alternative offer  \
# 7 How do you access the internet while shopping...
# Dial-up                                                                    0
# Mobile Internet                                                           84
# Wi-Fi                                                                     49
# All                                                                      133
#
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Change in price  \
# 7 How do you access the internet while shopping...
# Dial-up                                                           0
# Mobile Internet                                                  36
# Wi-Fi                                                             1
# All                                                              37
#
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Lack of trust  \
# 7 How do you access the internet while shopping...
# ...

# %%
pd.crosstab(index=df1['1Gender of respondent'], 
                             columns=[df1['17 Why did you abandon the “Bag”, “Shopping Cart”?']],
                             margins=True)
# Out:
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Better alternative offer  \
# 1Gender of respondent
# Female                                                                    98
# Male                                                                      35
# All                                                                      133
#
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Change in price  \
# 1Gender of respondent
# Female                                                           20
# Male                                                             17
# All                                                              37
#
# 17 Why did you abandon the “Bag”, “Shopping Cart”?  Lack of trust  \
# 1Gender of respondent
# Female                                                         20
# Male                                                           11
# All                                                            31
#
# ...
